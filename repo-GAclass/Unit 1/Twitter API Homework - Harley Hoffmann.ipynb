# %%
#importing requests package and tokens
import requests
from requests_oauthlib import OAuth1
url = 'https://api.twitter.com/1.1/account/verify_credentials.json'
auth = OAuth1('YWh5zjx5AqkzQucesPJd1Ffx8', 'DMVLJ5GkzqcWVo4LncuuMbPN79KotuTAp3W88ApmnLKtAOLFD5',
                  '74691997-AzJ7dR2NJRujEMTXEpnHs7vFXsCUUNSkeWozJJEec', 'XJEjNAtj5FjnpUi26e3LPERj5yE1j4oFPA7lpT8M2Ybvb')

# %%
import pandas as pd

# %%
req = requests.get(url, auth=auth)

# %%
##### Function 1

# %%
def find_user(screen_name, keys):
#create a dictionary to output values with entered keys and make json blob easier to work with
    returned_dict = {}
    user_objects = requests.get(f'https://api.twitter.com/1.1/users/lookup.json?screen_name={screen_name}', auth=auth)        
    user_objects_json = user_objects.json()
    for character in screen_name:
#check to remove @ if included
        if character == '@':
            screen_name.replace('@','')
#check to see if keys list value is empty or not
    if not keys:
        return user_objects_json
    else:
#if keys list is not empty then add the value of that key to the dictionary
        for key in keys:
            returned_dict[key] = user_objects_json[0][key]
        return returned_dict

# %%
find_user('GA',['name','screen_name','followers_count','friends_count'])
# Out:
# {'name': 'General Assembly',
#  'screen_name': 'GA',
#  'followers_count': 162574,
#  'friends_count': 5398}

# %%
##### Function 2

# %%
def find_hashtag(hashtag, count=None, search_type=None):
    hashtag_search = requests.get(f'https://api.twitter.com/1.1/search/tweets.json?q=%23{hashtag}&count={count}&result_type={search_type}', auth=auth)
    hashtag_search_json = hashtag_search.json()
    for character in hashtag:
#actually checking to remove hashtag because we've added %23 to the url above so we already have the hashtag
        if character == '#':
            hashtag.replace('#','')
#return the json for each of the parameters listed in the definition statement
    return hashtag_search_json

# %%
find_hashtag('DataScience', 20, 'mixed')
# Out:
# {'statuses': [{'created_at': 'Tue Mar 02 17:30:00 +0000 2021',
#    'id': 1366802986400444419,
#    'id_str': '1366802986400444419',
#    'text': '300 statistical concepts explained in simple English: https://t.co/cYm6a764nP \n\n#BigData #ML #DataScience… https://t.co/yssnc4YEp3',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'BigData', 'indices': [80, 88]},
#      {'text': 'ML', 'indices': [89, 92]},
#      {'text': 'DataScience', 'indices': [93, 105]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/cYm6a764nP',
#       'expanded_url': 'http://bit.ly/2THakBS',
#       'display_url': 'bit.ly/2THakBS',
#       'indices': [54, 77]},
#      {'url': 'https://t.co/yssnc4YEp3',
#       'expanded_url': 'https://twitter.com/i/web/status/1366802986400444419',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [107, 130]}]},
#    'metadata': {'result_type': 'popular', 'iso_language_code': 'en'},
#    'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 82364810,
#     'id_str': '82364810',
#     'name': 'MIT CSAIL',
#     'screen_name': 'MIT_CSAIL',
#     'location': 'Cambridge, MA',
#     'description': "MIT's largest research lab, the Computer Science & Artificial Intelligence Lab. https://t.co/CrZEGp7nEd #AI #ml #bigdata #iot #datascience #nlp",
#     'url': 'https://t.co/2YIudij4og',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/2YIudij4og',
#         'expanded_url': 'http://csail.mit.edu',
#         'display_url': 'csail.mit.edu',
#         'indices': [0, 23]}]},
#      'description': {'urls': [{'url': 'https://t.co/CrZEGp7nEd',
#         'expanded_url': 'http://instagram.com/mit_csail/',
#         'display_url': 'instagram.com/mit_csail/',
#         'indices': [80, 103]}]}},
#     'protected': False,
#     'followers_count': 163905,
#     'friends_count': 22080,
#     'listed_count': 2692,
#     'created_at': 'Wed Oct 14 13:55:58 +0000 2009',
#     'favourites_count': 2726,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': True,
#     'statuses_count': 4259,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '022330',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme15/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme15/bg.png',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/885505956272115712/U81HpDxb_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/885505956272115712/U81HpDxb_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/82364810/1499357815',
#     'profile_link_color': '0084B4',
#     'profile_sidebar_border_color': 'A8C7F7',
#     'profile_sidebar_fill_color': 'C0DFEC',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 350,
#    'favorite_count': 1148,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Mar 04 06:02:33 +0000 2021',
#    'id': 1367354757375959040,
#    'id_str': '1367354757375959040',
#    'text': 'National Educational Alliance for Technology (#NEAT) has collaborated with various industry leaders in educational-… https://t.co/DeeGL7uEmt',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'NEAT', 'indices': [46, 51]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/DeeGL7uEmt',
#       'expanded_url': 'https://twitter.com/i/web/status/1367354757375959040',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'result_type': 'popular', 'iso_language_code': 'en'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 2617066206,
#     'id_str': '2617066206',
#     'name': 'Dr. Ramesh Pokhriyal Nishank',
#     'screen_name': 'DrRPNishank',
#     'location': '',
#     'description': 'Union Cabinet Minister for Education, Government of India | Former Chief Minister of Uttarakhand | Author of 75 books | MP Haridwar.',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1093144,
#     'friends_count': 383,
#     'listed_count': 411,
#     'created_at': 'Fri Jul 11 10:12:50 +0000 2014',
#     'favourites_count': 20319,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': True,
#     'statuses_count': 34690,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1250023125191819266/Bx7kBZRg_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1250023125191819266/Bx7kBZRg_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2617066206/1614329814',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 24,
#    'favorite_count': 101,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Wed Mar 03 22:17:10 +0000 2021',
#    'id': 1367237641725485060,
#    'id_str': '1367237641725485060',
#    'text': '140 #MachineLearning Formulas for #DataScientists (FREE 17-page PDF): https://t.co/w5nIEzQHiT\n——————\n#BigData… https://t.co/gXHhvgYnYI',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'MachineLearning', 'indices': [4, 20]},
#      {'text': 'DataScientists', 'indices': [34, 49]},
#      {'text': 'BigData', 'indices': [101, 109]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/w5nIEzQHiT',
#       'expanded_url': 'http://dy.si/Z9o3ua2',
#       'display_url': 'dy.si/Z9o3ua2',
#       'indices': [70, 93]},
#      {'url': 'https://t.co/gXHhvgYnYI',
#       'expanded_url': 'https://twitter.com/i/web/status/1367237641725485060',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [111, 134]}]},
#    'metadata': {'result_type': 'popular', 'iso_language_code': 'en'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 534563976,
#     'id_str': '534563976',
#     'name': 'Kirk Borne',
#     'screen_name': 'KirkDBorne',
#     'location': 'Maryland, USA',
#     'description': 'Principal Data Scientist @BoozAllen. Global Speaker. Top #BigData #DataScience #AI Influencer. PhD Astrophysicist. (Views = my own) https://t.co/abP8DkYJY2 📊🔭',
#     'url': 'https://t.co/tWlmeuTlR7',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/tWlmeuTlR7',
#         'expanded_url': 'http://www.linkedin.com/in/kirkdborne',
#         'display_url': 'linkedin.com/in/kirkdborne',
#         'indices': [0, 23]}]},
#      'description': {'urls': [{'url': 'https://t.co/abP8DkYJY2',
#         'expanded_url': 'http://rocketdatascience.org',
#         'display_url': 'rocketdatascience.org',
#         'indices': [132, 155]}]}},
#     'protected': False,
#     'followers_count': 274103,
#     'friends_count': 8973,
#     'listed_count': 8306,
#     'created_at': 'Fri Mar 23 16:35:17 +0000 2012',
#     'favourites_count': 207571,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': True,
#     'statuses_count': 133385,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1112733580948635648/s-8d1avb_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1112733580948635648/s-8d1avb_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/534563976/1609822442',
#     'profile_link_color': '0084B4',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 28,
#    'favorite_count': 74,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Mar 04 18:03:48 +0000 2021',
#    'id': 1367536267932692482,
#    'id_str': '1367536267932692482',
#    'text': 'RT @MargaretSiegien: “We’ll never have true #AI without first understanding the #Brain \n@MargaretSiegien \n#ArtificialIntelligence #IoT #IIo…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'AI', 'indices': [44, 47]},
#      {'text': 'Brain', 'indices': [80, 86]},
#      {'text': 'ArtificialIntelligence', 'indices': [106, 129]},
#      {'text': 'IoT', 'indices': [130, 134]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'MargaretSiegien',
#       'name': 'Margaret Siegien 💫 🌎🚀',
#       'id': 777462371149156353,
#       'id_str': '777462371149156353',
#       'indices': [3, 19]},
#      {'screen_name': 'MargaretSiegien',
#       'name': 'Margaret Siegien 💫 🌎🚀',
#       'id': 777462371149156353,
#       'id_str': '777462371149156353',
#       'indices': [88, 104]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://rike.dev" rel="nofollow">friendly fem tech bot</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1143528514550927361,
#     'id_str': '1143528514550927361',
#     'name': 'FemTech_🖥👩🏽\u200d💻',
#     'screen_name': 'femtech_',
#     'location': 'Berlin, Deutschland',
#     'description': "I'm a friendly bot retweeting female developers, engineers, scientists and their stories. #girlswhocode #womenintech  #womeninstem\nMade by @frankanka",
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 19157,
#     'friends_count': 2,
#     'listed_count': 212,
#     'created_at': 'Tue Jun 25 14:36:58 +0000 2019',
#     'favourites_count': 94,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 1102749,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1143536112088035331/XDEmFAaj_normal.png',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1143536112088035331/XDEmFAaj_normal.png',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1143528514550927361/1561475338',
#     'profile_link_color': '91D2FA',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Mar 04 00:05:06 +0000 2021',
#     'id': 1367264805065752582,
#     'id_str': '1367264805065752582',
#     'text': '“We’ll never have true #AI without first understanding the #Brain \n@MargaretSiegien \n#ArtificialIntelligence #IoT… https://t.co/4VNi2RnFxp',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'AI', 'indices': [23, 26]},
#       {'text': 'Brain', 'indices': [59, 65]},
#       {'text': 'ArtificialIntelligence', 'indices': [85, 108]},
#       {'text': 'IoT', 'indices': [109, 113]}],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'MargaretSiegien',
#        'name': 'Margaret Siegien 💫 🌎🚀',
#        'id': 777462371149156353,
#        'id_str': '777462371149156353',
#        'indices': [67, 83]}],
#      'urls': [{'url': 'https://t.co/4VNi2RnFxp',
#        'expanded_url': 'https://twitter.com/i/web/status/1367264805065752582',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [115, 138]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 777462371149156353,
#      'id_str': '777462371149156353',
#      'name': 'Margaret Siegien 💫 🌎🚀',
#      'screen_name': 'MargaretSiegien',
#      'location': 'Chicago , IL , USA',
#      'description': 'President at @iTrucker_ Passionate about #tech #AI #HealthTech #Innovation #Space #SocialMedia #futureofwork #Science #SupplyChain #VR #AR #WomeninTech #Robotic',
#      'url': 'https://t.co/LhBLP7vx3s',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/LhBLP7vx3s',
#          'expanded_url': 'http://www.itrucker.com/',
#          'display_url': 'itrucker.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 6830,
#      'friends_count': 2311,
#      'listed_count': 115,
#      'created_at': 'Sun Sep 18 11:00:48 +0000 2016',
#      'favourites_count': 34115,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 17454,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1329686190853861376/ufKf5KkY_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1329686190853861376/ufKf5KkY_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/777462371149156353/1595750021',
#      'profile_link_color': '1B95E0',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 45,
#     'favorite_count': 12,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 45,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Mar 04 18:03:47 +0000 2021',
#    'id': 1367536265386549251,
#    'id_str': '1367536265386549251',
#    'text': 'RT @ankitjnyadav: 150+ Free Github Books. #BigData #Analytics #DataScience #IoT #IIoT #PyTorch #Python #RStats #TensorFlow #Java #JavaScrip…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'BigData', 'indices': [42, 50]},
#      {'text': 'Analytics', 'indices': [51, 61]},
#      {'text': 'DataScience', 'indices': [62, 74]},
#      {'text': 'IoT', 'indices': [75, 79]},
#      {'text': 'IIoT', 'indices': [80, 85]},
#      {'text': 'PyTorch', 'indices': [86, 94]},
#      {'text': 'Python', 'indices': [95, 102]},
#      {'text': 'RStats', 'indices': [103, 110]},
#      {'text': 'TensorFlow', 'indices': [111, 122]},
#      {'text': 'Java', 'indices': [123, 128]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'ankitjnyadav',
#       'name': 'Ankit Yadav',
#       'id': 962211459806650368,
#       'id_str': '962211459806650368',
#       'indices': [3, 16]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1148824688275021824,
#     'id_str': '1148824688275021824',
#     'name': 'Reynaldo Reyes',
#     'screen_name': 'Reynald93063819',
#     'location': '',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 3368,
#     'friends_count': 4951,
#     'listed_count': 13,
#     'created_at': 'Wed Jul 10 05:22:04 +0000 2019',
#     'favourites_count': 162787,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 164894,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1148824831997042688/5O83O-2R_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1148824831997042688/5O83O-2R_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1148824688275021824/1588930335',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Mar 04 13:13:05 +0000 2021',
#     'id': 1367463105383436288,
#     'id_str': '1367463105383436288',
#     'text': '150+ Free Github Books. #BigData #Analytics #DataScience #IoT #IIoT #PyTorch #Python #RStats #TensorFlow #Java… https://t.co/84MXwZaQPt',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'BigData', 'indices': [24, 32]},
#       {'text': 'Analytics', 'indices': [33, 43]},
#       {'text': 'DataScience', 'indices': [44, 56]},
#       {'text': 'IoT', 'indices': [57, 61]},
#       {'text': 'IIoT', 'indices': [62, 67]},
#       {'text': 'PyTorch', 'indices': [68, 76]},
#       {'text': 'Python', 'indices': [77, 84]},
#       {'text': 'RStats', 'indices': [85, 92]},
#       {'text': 'TensorFlow', 'indices': [93, 104]},
#       {'text': 'Java', 'indices': [105, 110]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/84MXwZaQPt',
#        'expanded_url': 'https://twitter.com/i/web/status/1367463105383436288',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [112, 135]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 962211459806650368,
#      'id_str': '962211459806650368',
#      'name': 'Ankit Yadav',
#      'screen_name': 'ankitjnyadav',
#      'location': 'Pune, India',
#      'description': 'Patriotic. 🇮🇳 Tech Enthusiast.',
#      'url': 'https://t.co/pjfoPhGh0b',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/pjfoPhGh0b',
#          'expanded_url': 'https://linktr.ee/ankitjnyadav',
#          'display_url': 'linktr.ee/ankitjnyadav',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 82,
#      'friends_count': 552,
#      'listed_count': 2,
#      'created_at': 'Sat Feb 10 06:27:43 +0000 2018',
#      'favourites_count': 2935,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 1889,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1125058470825172993/T_5R_WSE_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1125058470825172993/T_5R_WSE_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/962211459806650368/1612341428',
#      'profile_link_color': '1B95E0',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 37,
#     'favorite_count': 18,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 37,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Mar 04 18:03:46 +0000 2021',
#    'id': 1367536259216764929,
#    'id_str': '1367536259216764929',
#    'text': "RT @gp_pulipaka: Free O'Reilly Hardware and IoT eBooks (Chapters). #BigData #Analytics #DataScience #AI #MachineLearning #IoT #IIoT #Python…",
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'BigData', 'indices': [67, 75]},
#      {'text': 'Analytics', 'indices': [76, 86]},
#      {'text': 'DataScience', 'indices': [87, 99]},
#      {'text': 'AI', 'indices': [100, 103]},
#      {'text': 'MachineLearning', 'indices': [104, 120]},
#      {'text': 'IoT', 'indices': [121, 125]},
#      {'text': 'IIoT', 'indices': [126, 131]},
#      {'text': 'Python', 'indices': [132, 139]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'gp_pulipaka',
#       'name': 'Dr. Ganapathi Pulipaka',
#       'id': 4263007693,
#       'id_str': '4263007693',
#       'indices': [3, 15]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://andrewmmorris.com/" rel="nofollow">Autism_twitter</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 2358562603,
#     'id_str': '2358562603',
#     'name': 'Andrew Morris',
#     'screen_name': 'andrewmorrisuk',
#     'location': 'Bedford',
#     'description': 'Passionate about how IT solutions can bring positive value to our business and personal lives. Proud #autisticparent',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 12713,
#     'friends_count': 967,
#     'listed_count': 319,
#     'created_at': 'Sun Feb 23 21:58:16 +0000 2014',
#     'favourites_count': 3161,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 509909,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1138114915619749888/1e0u-1mE_normal.png',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1138114915619749888/1e0u-1mE_normal.png',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu May 14 14:42:24 +0000 2020',
#     'id': 1260943551099211777,
#     'id_str': '1260943551099211777',
#     'text': "Free O'Reilly Hardware and IoT eBooks (Chapters). #BigData #Analytics #DataScience #AI #MachineLearning #IoT #IIoT… https://t.co/PGugyA3x2g",
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'BigData', 'indices': [50, 58]},
#       {'text': 'Analytics', 'indices': [59, 69]},
#       {'text': 'DataScience', 'indices': [70, 82]},
#       {'text': 'AI', 'indices': [83, 86]},
#       {'text': 'MachineLearning', 'indices': [87, 103]},
#       {'text': 'IoT', 'indices': [104, 108]},
#       {'text': 'IIoT', 'indices': [109, 114]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/PGugyA3x2g',
#        'expanded_url': 'https://twitter.com/i/web/status/1260943551099211777',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [116, 139]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://buffer.com" rel="nofollow">Buffer</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 4263007693,
#      'id_str': '4263007693',
#      'name': 'Dr. Ganapathi Pulipaka',
#      'screen_name': 'gp_pulipaka',
#      'location': 'Redondo Beach, CA',
#      'description': 'Chief #AI #HPC Scientist | #Speaker | PostDoc CS, PhD | Bestselling #Author | 18.4M V | Top #BigData #DataScience #MachineLearning #IIoT Influencer @Onalytica',
#      'url': 'https://t.co/eYyaJsEcfw',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/eYyaJsEcfw',
#          'expanded_url': 'http://www.gppulipaka.org',
#          'display_url': 'gppulipaka.org',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 109894,
#      'friends_count': 22705,
#      'listed_count': 3566,
#      'created_at': 'Tue Nov 17 02:19:09 +0000 2015',
#      'favourites_count': 9,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 61381,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1354974939887988736/P9wzBxgk_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1354974939887988736/P9wzBxgk_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4263007693/1605195322',
#      'profile_link_color': 'DD2E44',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 42,
#     'favorite_count': 25,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 42,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Mar 04 18:03:43 +0000 2021',
#    'id': 1367536245530763266,
#    'id_str': '1367536245530763266',
#    'text': 'RT @MargaretSiegien: “We’ll never have true #AI without first understanding the #Brain \n@MargaretSiegien \n#ArtificialIntelligence #IoT #IIo…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'AI', 'indices': [44, 47]},
#      {'text': 'Brain', 'indices': [80, 86]},
#      {'text': 'ArtificialIntelligence', 'indices': [106, 129]},
#      {'text': 'IoT', 'indices': [130, 134]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'MargaretSiegien',
#       'name': 'Margaret Siegien 💫 🌎🚀',
#       'id': 777462371149156353,
#       'id_str': '777462371149156353',
#       'indices': [3, 19]},
#      {'screen_name': 'MargaretSiegien',
#       'name': 'Margaret Siegien 💫 🌎🚀',
#       'id': 777462371149156353,
#       'id_str': '777462371149156353',
#       'indices': [88, 104]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://adam-spice.online" rel="nofollow">GnutsBot</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1266133633389060097,
#     'id_str': '1266133633389060097',
#     'name': 'Gnuts about Code',
#     'screen_name': 'CodeGnuts',
#     'location': '',
#     'description': 'Just a bot helping coders show their progress. Automation built in #NodeJs by @AdamSpiceOnline. #100DaysOfCode',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 4348,
#     'friends_count': 0,
#     'listed_count': 70,
#     'created_at': 'Thu May 28 22:26:07 +0000 2020',
#     'favourites_count': 134163,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 773302,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1266134298429517824/Gxv_xYd7_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1266134298429517824/Gxv_xYd7_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1266133633389060097/1590708060',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Mar 04 00:05:06 +0000 2021',
#     'id': 1367264805065752582,
#     'id_str': '1367264805065752582',
#     'text': '“We’ll never have true #AI without first understanding the #Brain \n@MargaretSiegien \n#ArtificialIntelligence #IoT… https://t.co/4VNi2RnFxp',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'AI', 'indices': [23, 26]},
#       {'text': 'Brain', 'indices': [59, 65]},
#       {'text': 'ArtificialIntelligence', 'indices': [85, 108]},
#       {'text': 'IoT', 'indices': [109, 113]}],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'MargaretSiegien',
#        'name': 'Margaret Siegien 💫 🌎🚀',
#        'id': 777462371149156353,
#        'id_str': '777462371149156353',
#        'indices': [67, 83]}],
#      'urls': [{'url': 'https://t.co/4VNi2RnFxp',
#        'expanded_url': 'https://twitter.com/i/web/status/1367264805065752582',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [115, 138]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 777462371149156353,
#      'id_str': '777462371149156353',
#      'name': 'Margaret Siegien 💫 🌎🚀',
#      'screen_name': 'MargaretSiegien',
#      'location': 'Chicago , IL , USA',
#      'description': 'President at @iTrucker_ Passionate about #tech #AI #HealthTech #Innovation #Space #SocialMedia #futureofwork #Science #SupplyChain #VR #AR #WomeninTech #Robotic',
#      'url': 'https://t.co/LhBLP7vx3s',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/LhBLP7vx3s',
#          'expanded_url': 'http://www.itrucker.com/',
#          'display_url': 'itrucker.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 6830,
#      'friends_count': 2311,
#      'listed_count': 115,
#      'created_at': 'Sun Sep 18 11:00:48 +0000 2016',
#      'favourites_count': 34115,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 17454,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1329686190853861376/ufKf5KkY_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1329686190853861376/ufKf5KkY_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/777462371149156353/1595750021',
#      'profile_link_color': '1B95E0',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 45,
#     'favorite_count': 12,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 45,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Mar 04 18:03:39 +0000 2021',
#    'id': 1367536229479297025,
#    'id_str': '1367536229479297025',
#    'text': 'RT @Mlearning_ai: The Coolest #NeuralNetworks Which You Can Try Right Now \nby Mark Vassilevskiy https://t.co/t62FWb1Q4R \n#machinelearning #…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'NeuralNetworks', 'indices': [30, 45]},
#      {'text': 'machinelearning', 'indices': [121, 137]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'Mlearning_ai',
#       'name': 'machine learning',
#       'id': 725664829,
#       'id_str': '725664829',
#       'indices': [3, 16]}],
#     'urls': [{'url': 'https://t.co/t62FWb1Q4R',
#       'expanded_url': 'https://link.medium.com/Po3oqK28leb',
#       'display_url': 'link.medium.com/Po3oqK28leb',
#       'indices': [96, 119]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twinybots.com" rel="nofollow">TwinyBots</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1197104147696439298,
#     'id_str': '1197104147696439298',
#     'name': 'CORIZANCE - Connected Risk Management Made Easy',
#     'screen_name': 'corizance',
#     'location': 'linkedin.com/company/corizance',
#     'description': 'Connected Risk Intelligence platform re-shaping non-financial risk management #Riskmanagement #Compliance #AI #Regtech #Fintech #Analytics #Data #Ecosystem #UK',
#     'url': 'https://t.co/i0OKZXmJIV',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/i0OKZXmJIV',
#         'expanded_url': 'http://www.corizance.com',
#         'display_url': 'corizance.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 492,
#     'friends_count': 436,
#     'listed_count': 13,
#     'created_at': 'Wed Nov 20 10:47:42 +0000 2019',
#     'favourites_count': 4845,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 38201,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1223176339697565697/q38i7r9K_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1223176339697565697/q38i7r9K_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1197104147696439298/1613210035',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Mar 04 16:50:31 +0000 2021',
#     'id': 1367517825355702286,
#     'id_str': '1367517825355702286',
#     'text': 'The Coolest #NeuralNetworks Which You Can Try Right Now \nby Mark Vassilevskiy https://t.co/t62FWb1Q4R… https://t.co/lzrFsOJXJY',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'NeuralNetworks', 'indices': [12, 27]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/t62FWb1Q4R',
#        'expanded_url': 'https://link.medium.com/Po3oqK28leb',
#        'display_url': 'link.medium.com/Po3oqK28leb',
#        'indices': [78, 101]},
#       {'url': 'https://t.co/lzrFsOJXJY',
#        'expanded_url': 'https://twitter.com/i/web/status/1367517825355702286',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [103, 126]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 725664829,
#      'id_str': '725664829',
#      'name': 'machine learning',
#      'screen_name': 'Mlearning_ai',
#      'location': '',
#      'description': 'we solve #business problems by combining #machinelearning & #art 🟠 #MLsoGood #next_AI_architects #sztucznainteligencja',
#      'url': 'https://t.co/ikk9zpE22h',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/ikk9zpE22h',
#          'expanded_url': 'https://linktr.ee/mlearning',
#          'display_url': 'linktr.ee/mlearning',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 4172,
#      'friends_count': 209,
#      'listed_count': 148,
#      'created_at': 'Mon Jul 30 09:00:05 +0000 2012',
#      'favourites_count': 1067,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 16673,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '94B3C2',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1198670629433724928/V-cPfdPX_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1198670629433724928/V-cPfdPX_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/725664829/1611609585',
#      'profile_link_color': '0084B4',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': False,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 9,
#     'favorite_count': 6,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 9,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Mar 04 18:03:39 +0000 2021',
#    'id': 1367536228304887810,
#    'id_str': '1367536228304887810',
#    'text': 'RT @kdnuggets: Data Engineering — the Cousin of #DataScience, is Troublesome #KDN https://t.co/hrX73eYv4c',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'DataScience', 'indices': [48, 60]},
#      {'text': 'KDN', 'indices': [77, 81]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'kdnuggets',
#       'name': 'KDnuggets',
#       'id': 20167623,
#       'id_str': '20167623',
#       'indices': [3, 13]}],
#     'urls': [{'url': 'https://t.co/hrX73eYv4c',
#       'expanded_url': 'http://ow.ly/aGeO30rz3Ll',
#       'display_url': 'ow.ly/aGeO30rz3Ll',
#       'indices': [82, 105]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 9948722,
#     'id_str': '9948722',
#     'name': 'LetitiaGreen MBA MEd',
#     'screen_name': 'VaActiveAngels',
#     'location': 'Mid-Atlantic Region',
#     'description': 'Angel group founder (‘05- ), @UVAEngineers Instructor for 5 yrs. Startup consultant, RE investor. Parler @wifeSailorPrivateEquity, RUMBLE @Tish4Tech',
#     'url': 'https://t.co/kziXamGcl7',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/kziXamGcl7',
#         'expanded_url': 'http://www.virginiaactiveangelnetwork.com',
#         'display_url': 'virginiaactiveangelnetwork.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1307,
#     'friends_count': 163,
#     'listed_count': 382,
#     'created_at': 'Sun Nov 04 21:57:02 +0000 2007',
#     'favourites_count': 49823,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 23299,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/2635663697/3d577f01155cf76067562b2687417c95_normal.jpeg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/2635663697/3d577f01155cf76067562b2687417c95_normal.jpeg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/9948722/1487373078',
#     'profile_link_color': '0084B4',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Mar 04 18:02:09 +0000 2021',
# ...
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 2257558088,
#     'id_str': '2257558088',
#     'name': 'Atanas G. Atanasov',
#     'screen_name': '_atanas_',
#     'location': '',
#     'description': 'Innovations in Molecular Medicine and Digital Health. Principal Investigator of LBI-DHPS. Editor-in-Chief of #CRBIOTECH. Leader of #DHPSP and #INPST.',
#     'url': 'https://t.co/9UFUpYWLai',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/9UFUpYWLai',
#         'expanded_url': 'https://digitalpatientsafety.com/atanas-g-atanasov/',
#         'display_url': 'digitalpatientsafety.com/atanas-g-atana…',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 117974,
#     'friends_count': 73613,
#     'listed_count': 1694,
#     'created_at': 'Sun Dec 22 10:30:36 +0000 2013',
#     'favourites_count': 95215,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 55936,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '03B0FA',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme16/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme16/bg.gif',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/883586748244262912/o90PC6JY_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/883586748244262912/o90PC6JY_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2257558088/1612690098',
#     'profile_link_color': 'FF00FF',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': 'C0DFEC',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Wed Mar 03 16:05:18 +0000 2021',
#     'id': 1367144057877581825,
#     'id_str': '1367144057877581825',
#     'text': 'High-dimensional hepatopath #Data analysis by #MachineLearning--predicting HBV-related fibrosis \n\n#DHPSP… https://t.co/4dQjUsjmmX',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'Data', 'indices': [28, 33]},
#       {'text': 'MachineLearning', 'indices': [46, 62]},
#       {'text': 'DHPSP', 'indices': [98, 104]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/4dQjUsjmmX',
#        'expanded_url': 'https://twitter.com/i/web/status/1367144057877581825',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [106, 129]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1328160458138738688,
#      'id_str': '1328160458138738688',
#      'name': 'Siva Sai',
#      'screen_name': '_Sivasai',
#      'location': '',
#      'description': '',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 23,
#      'friends_count': 138,
#      'listed_count': 1,
#      'created_at': 'Mon Nov 16 02:19:13 +0000 2020',
#      'favourites_count': 265,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 263,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#      'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': True,
#      'default_profile_image': True,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': True,
#     'quoted_status_id': 1367064744524460035,
#     'quoted_status_id_str': '1367064744524460035',
#     'quoted_status': {'created_at': 'Wed Mar 03 10:50:08 +0000 2021',
#      'id': 1367064744524460035,
#      'id_str': '1367064744524460035',
#      'text': 'High-dimensional hepatopath data analysis by machine learning for predicting HBV-related fibrosis \n\n#DHPSP… https://t.co/sn4fDLU77R',
#      'truncated': True,
#      'entities': {'hashtags': [{'text': 'DHPSP', 'indices': [100, 106]}],
#       'symbols': [],
#       'user_mentions': [],
#       'urls': [{'url': 'https://t.co/sn4fDLU77R',
#         'expanded_url': 'https://twitter.com/i/web/status/1367064744524460035',
#         'display_url': 'twitter.com/i/web/status/1…',
#         'indices': [108, 131]}]},
#      'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#      'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#      'in_reply_to_status_id': None,
#      'in_reply_to_status_id_str': None,
#      'in_reply_to_user_id': None,
#      'in_reply_to_user_id_str': None,
#      'in_reply_to_screen_name': None,
#      'user': {'id': 2257558088,
#       'id_str': '2257558088',
#       'name': 'Atanas G. Atanasov',
#       'screen_name': '_atanas_',
#       'location': '',
#       'description': 'Innovations in Molecular Medicine and Digital Health. Principal Investigator of LBI-DHPS. Editor-in-Chief of #CRBIOTECH. Leader of #DHPSP and #INPST.',
#       'url': 'https://t.co/9UFUpYWLai',
#       'entities': {'url': {'urls': [{'url': 'https://t.co/9UFUpYWLai',
#           'expanded_url': 'https://digitalpatientsafety.com/atanas-g-atanasov/',
#           'display_url': 'digitalpatientsafety.com/atanas-g-atana…',
#           'indices': [0, 23]}]},
#        'description': {'urls': []}},
#       'protected': False,
#       'followers_count': 117974,
#       'friends_count': 73613,
#       'listed_count': 1694,
#       'created_at': 'Sun Dec 22 10:30:36 +0000 2013',
#       'favourites_count': 95215,
#       'utc_offset': None,
#       'time_zone': None,
#       'geo_enabled': True,
#       'verified': False,
#       'statuses_count': 55936,
#       'lang': None,
#       'contributors_enabled': False,
#       'is_translator': False,
#       'is_translation_enabled': False,
#       'profile_background_color': '03B0FA',
#       'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme16/bg.gif',
#       'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme16/bg.gif',
#       'profile_background_tile': True,
#       'profile_image_url': 'http://pbs.twimg.com/profile_images/883586748244262912/o90PC6JY_normal.jpg',
#       'profile_image_url_https': 'https://pbs.twimg.com/profile_images/883586748244262912/o90PC6JY_normal.jpg',
#       'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2257558088/1612690098',
#       'profile_link_color': 'FF00FF',
#       'profile_sidebar_border_color': '000000',
#       'profile_sidebar_fill_color': 'C0DFEC',
#       'profile_text_color': '333333',
#       'profile_use_background_image': True,
#       'has_extended_profile': True,
#       'default_profile': False,
#       'default_profile_image': False,
#       'following': False,
#       'follow_request_sent': False,
#       'notifications': False,
#       'translator_type': 'none'},
#      'geo': None,
#      'coordinates': None,
#      'place': None,
#      'contributors': None,
#      'is_quote_status': False,
#      'retweet_count': 28,
#      'favorite_count': 31,
#      'favorited': False,
#      'retweeted': False,
#      'possibly_sensitive': False,
#      'lang': 'en'},
#     'retweet_count': 17,
#     'favorite_count': 9,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': True,
#    'quoted_status_id': 1367064744524460035,
#    'quoted_status_id_str': '1367064744524460035',
#    'retweet_count': 17,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Mar 04 18:02:53 +0000 2021',
#    'id': 1367536036205756424,
#    'id_str': '1367536036205756424',
#    'text': 'RT @ipfconline1: 10 #DeepLearning Jokes That You’ll Only Understand If You Really Know Deep Learning \n\nhttps://t.co/EzM8egLgNC v/ @theclick…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'DeepLearning', 'indices': [20, 33]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'ipfconline1',
#       'name': 'ipfconline',
#       'id': 705539763349164032,
#       'id_str': '705539763349164032',
#       'indices': [3, 15]}],
#     'urls': [{'url': 'https://t.co/EzM8egLgNC',
#       'expanded_url': 'https://theclickreader.com/ten-deep-learning-jokes-that-youll-only-understand-if-you-really-know-deep-learning',
#       'display_url': 'theclickreader.com/ten-deep-learn…',
#       'indices': [103, 126]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://itunes.apple.com/us/app/twitter/id409789998?mt=12" rel="nofollow">Twitter for Mac</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 771684014,
#     'id_str': '771684014',
#     'name': 'David',
#     'screen_name': 'compascafe',
#     'location': '',
#     'description': 'Dos informáticos desempleados = Podcast./ Tres = una Start up .',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 180,
#     'friends_count': 2321,
#     'listed_count': 2,
#     'created_at': 'Tue Aug 21 15:11:33 +0000 2012',
#     'favourites_count': 28588,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 5527,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1294764898078068736/d3gmRZkT_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1294764898078068736/d3gmRZkT_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/771684014/1589482345',
#     'profile_link_color': '19CF86',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Mar 04 15:30:05 +0000 2021',
#     'id': 1367497581937459209,
#     'id_str': '1367497581937459209',
#     'text': '10 #DeepLearning Jokes That You’ll Only Understand If You Really Know Deep Learning \n\nhttps://t.co/EzM8egLgNC v/… https://t.co/FN5GZKWcoa',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'DeepLearning', 'indices': [3, 16]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/EzM8egLgNC',
#        'expanded_url': 'https://theclickreader.com/ten-deep-learning-jokes-that-youll-only-understand-if-you-really-know-deep-learning',
#        'display_url': 'theclickreader.com/ten-deep-learn…',
#        'indices': [86, 109]},
#       {'url': 'https://t.co/FN5GZKWcoa',
#        'expanded_url': 'https://twitter.com/i/web/status/1367497581937459209',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [114, 137]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://twittimer.com" rel="nofollow">Twittimer</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 705539763349164032,
#      'id_str': '705539763349164032',
#      'name': 'ipfconline',
#      'screen_name': 'ipfconline1',
#      'location': 'Marseille, France',
#      'description': 'Digital Transformation Consulting \n#AI #MachineLearning #DeepLearning \n#5G #DataScience #AIEthics\n#CloudComputing #Fintech\n#DigitalMarketing',
#      'url': 'https://t.co/AWsrN4R5NF',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/AWsrN4R5NF',
#          'expanded_url': 'http://ipfconline.fr/contacts-eng.html',
#          'display_url': 'ipfconline.fr/contacts-eng.h…',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 112745,
#      'friends_count': 107282,
#      'listed_count': 7802,
#      'created_at': 'Thu Mar 03 23:46:02 +0000 2016',
#      'favourites_count': 140320,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 182875,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/729065804004769793/St2_Pum9_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/729065804004769793/St2_Pum9_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/705539763349164032/1543420399',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 18,
#     'favorite_count': 16,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 18,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': True,
#    'lang': 'en'}],
#  'search_metadata': {'completed_in': 0.095,
#   'max_id': 1367536267932692482,
#   'max_id_str': '1367536267932692482',
#   'next_results': '?max_id=1366802986400444418&q=%23DataScience&count=20&include_entities=1&result_type=mixed',
#   'query': '%23DataScience',
#   'refresh_url': '?since_id=1367536267932692482&q=%23DataScience&result_type=mixed&include_entities=1',
#   'count': 20,
#   'since_id': 0,
#   'since_id_str': '0'}}

# %%
##### Function 3

# %%
def get_followers(screen_name, keys, to_df: bool):
    list_of_followers = []
    user_followers = requests.get(f'https://api.twitter.com/1.1/followers/list.json?screen_name={screen_name}', auth=auth)
    user_followers_json = user_followers.json()
    for character in screen_name:
#check to remove @ if included
        if character == '@':
                screen_name == screen_name.replace('@','')
#grabbing all the user objects in the list, separately, and then grabbing each key that match the inputs
#this is similar to question 1 but just a list of many users, so we have to do a double for loop
    for user in user_followers_json['users']:
# create a new single user since each user in nested in users and match the keys from the keys input
        single_user = {}
        for key in keys:
            single_user[key] = user[key]
# Now add the single user to the list of followers and continue looping through each user in users
        list_of_followers.append(single_user)
#if df is true, then put the result in a dataframe
    if to_df == True:
        return pd.DataFrame(list_of_followers)
    else:
        return list_of_followers

# %%
import pandas as pd
get_followers('GA', ['screen_name','followers_count'], to_df=True)
# Out:
#         screen_name  followers_count
# 0           rarinke              272
# 1   heyitsdominique               23
# 2           ice_d3v                1
# 3       MonaAldaw16                4
# 4    NotoriouslyDvs               44
# 5     vsourz_agency               46
# 6         pbekkilla                8
# 7   the_codersguild              274
# 8     caveat_images               10
# 9         prompt_io             1057
# 10  McDaniel_InksBz               55
# 11     Laura_Tombia              268
# 12      brittcambas               49
# 13       RektRalph4               40
# 14    mahedi_dreams              127
# 15        mafromist              155
# 16   TheStartupsMag             8479
# 17  StableGeniu1745               10
# 18   freddieblicher              296
# 19         Brydgcom               81

# %%
user_followers_json
# Out:
# {'users': [{'id': 847998020364980225,
#    'id_str': '847998020364980225',
#    'name': 'DEE',
#    'screen_name': 'ice_d3v',
#    'location': 'London',
#    'description': '',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 1,
#    'friends_count': 12,
#    'listed_count': 0,
#    'created_at': 'Sat Apr 01 02:24:18 +0000 2017',
#    'favourites_count': 16,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 5,
#    'lang': None,
#    'status': {'created_at': 'Thu Mar 04 16:04:56 +0000 2021',
#     'id': 1367506353942646786,
#     'id_str': '1367506353942646786',
#     'text': '@jesss_codes Wait why are there time estimates on this? take as long as you want and learn how YOU learn',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'jesss_codes',
#        'name': 'Jessica',
#        'id': 1275056773443973124,
#        'id_str': '1275056773443973124',
#        'indices': [0, 12]}],
#      'urls': []},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': 1367057476496064514,
#     'in_reply_to_status_id_str': '1367057476496064514',
#     'in_reply_to_user_id': 1275056773443973124,
#     'in_reply_to_user_id_str': '1275056773443973124',
#     'in_reply_to_screen_name': 'jesss_codes',
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 0,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1242782138455543810/UBxXtPQh_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1242782138455543810/UBxXtPQh_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/847998020364980225/1561863058',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 1348902569742053378,
#    'id_str': '1348902569742053378',
#    'name': 'Mona..',
#    'screen_name': 'MonaAldaw16',
#    'location': '',
#    'description': 'تذكر بأنك لست وحيد.',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 4,
#    'friends_count': 70,
#    'listed_count': 0,
#    'created_at': 'Tue Jan 12 08:01:20 +0000 2021',
#    'favourites_count': 66,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 16,
#    'lang': None,
#    'status': {'created_at': 'Mon Mar 01 19:45:21 +0000 2021',
#     'id': 1366474661882699780,
#     'id_str': '1366474661882699780',
#     'text': 'RT @ahmed_mahallawy: new profile cover 🥳\n#newcoverpic https://t.co/LAeDhb68Dx',
#     'truncated': False,
#     'entities': {'hashtags': [{'text': 'newcoverpic', 'indices': [41, 53]}],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'ahmed_mahallawy',
#        'name': 'Mahallawy (still 🏡)',
#        'id': 194465010,
#        'id_str': '194465010',
#        'indices': [3, 19]}],
#      'urls': [],
#      'media': [{'id': 1366384575904165895,
#        'id_str': '1366384575904165895',
#        'indices': [54, 77],
#        'media_url': 'http://pbs.twimg.com/media/EvZfiElXMAc9Hn3.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/EvZfiElXMAc9Hn3.jpg',
#        'url': 'https://t.co/LAeDhb68Dx',
#        'display_url': 'pic.twitter.com/LAeDhb68Dx',
#        'expanded_url': 'https://twitter.com/ahmed_mahallawy/status/1366384927663673347/photo/1',
#        'type': 'photo',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'medium': {'w': 1200, 'h': 538, 'resize': 'fit'},
#         'small': {'w': 680, 'h': 305, 'resize': 'fit'},
#         'large': {'w': 2048, 'h': 918, 'resize': 'fit'}},
#        'source_status_id': 1366384927663673347,
#        'source_status_id_str': '1366384927663673347',
#        'source_user_id': 194465010,
#        'source_user_id_str': '194465010'}]},
#     'extended_entities': {'media': [{'id': 1366384575904165895,
#        'id_str': '1366384575904165895',
#        'indices': [54, 77],
#        'media_url': 'http://pbs.twimg.com/media/EvZfiElXMAc9Hn3.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/EvZfiElXMAc9Hn3.jpg',
#        'url': 'https://t.co/LAeDhb68Dx',
#        'display_url': 'pic.twitter.com/LAeDhb68Dx',
#        'expanded_url': 'https://twitter.com/ahmed_mahallawy/status/1366384927663673347/photo/1',
#        'type': 'photo',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'medium': {'w': 1200, 'h': 538, 'resize': 'fit'},
#         'small': {'w': 680, 'h': 305, 'resize': 'fit'},
#         'large': {'w': 2048, 'h': 918, 'resize': 'fit'}},
#        'source_status_id': 1366384927663673347,
#        'source_status_id_str': '1366384927663673347',
#        'source_user_id': 194465010,
#        'source_user_id_str': '194465010'}]},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'retweeted_status': {'created_at': 'Mon Mar 01 13:48:47 +0000 2021',
#      'id': 1366384927663673347,
#      'id_str': '1366384927663673347',
#      'text': 'new profile cover 🥳\n#newcoverpic https://t.co/LAeDhb68Dx',
#      'truncated': False,
#      'entities': {'hashtags': [{'text': 'newcoverpic', 'indices': [20, 32]}],
#       'symbols': [],
#       'user_mentions': [],
#       'urls': [],
#       'media': [{'id': 1366384575904165895,
#         'id_str': '1366384575904165895',
#         'indices': [33, 56],
#         'media_url': 'http://pbs.twimg.com/media/EvZfiElXMAc9Hn3.jpg',
#         'media_url_https': 'https://pbs.twimg.com/media/EvZfiElXMAc9Hn3.jpg',
#         'url': 'https://t.co/LAeDhb68Dx',
#         'display_url': 'pic.twitter.com/LAeDhb68Dx',
#         'expanded_url': 'https://twitter.com/ahmed_mahallawy/status/1366384927663673347/photo/1',
#         'type': 'photo',
#         'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#          'medium': {'w': 1200, 'h': 538, 'resize': 'fit'},
#          'small': {'w': 680, 'h': 305, 'resize': 'fit'},
#          'large': {'w': 2048, 'h': 918, 'resize': 'fit'}}}]},
#      'extended_entities': {'media': [{'id': 1366384575904165895,
#         'id_str': '1366384575904165895',
#         'indices': [33, 56],
#         'media_url': 'http://pbs.twimg.com/media/EvZfiElXMAc9Hn3.jpg',
#         'media_url_https': 'https://pbs.twimg.com/media/EvZfiElXMAc9Hn3.jpg',
#         'url': 'https://t.co/LAeDhb68Dx',
#         'display_url': 'pic.twitter.com/LAeDhb68Dx',
#         'expanded_url': 'https://twitter.com/ahmed_mahallawy/status/1366384927663673347/photo/1',
#         'type': 'photo',
#         'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#          'medium': {'w': 1200, 'h': 538, 'resize': 'fit'},
#          'small': {'w': 680, 'h': 305, 'resize': 'fit'},
#          'large': {'w': 2048, 'h': 918, 'resize': 'fit'}}}]},
#      'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#      'in_reply_to_status_id': None,
#      'in_reply_to_status_id_str': None,
#      'in_reply_to_user_id': None,
#      'in_reply_to_user_id_str': None,
#      'in_reply_to_screen_name': None,
#      'geo': None,
#      'coordinates': None,
#      'place': None,
#      'contributors': None,
#      'is_quote_status': False,
#      'retweet_count': 1,
#      'favorite_count': 30,
#      'favorited': False,
#      'retweeted': False,
#      'possibly_sensitive': False,
#      'lang': 'en'},
#     'is_quote_status': False,
#     'retweet_count': 1,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1348904207584292865/k13MA-6O_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1348904207584292865/k13MA-6O_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1348902569742053378/1610439033',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 289814036,
#    'id_str': '289814036',
#    'name': 'Nonchalant Leo',
#    'screen_name': 'NotoriouslyDvs',
#    'location': 'New York, NY',
#    'description': "Characterize people by their actions, & you'll never be fooled by their words.",
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 44,
#    'friends_count': 218,
#    'listed_count': 0,
#    'created_at': 'Fri Apr 29 07:56:29 +0000 2011',
#    'favourites_count': 64,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 259,
#    'lang': None,
#    'status': {'created_at': 'Sat Feb 27 00:41:10 +0000 2021',
#     'id': 1365461939929890818,
#     'id_str': '1365461939929890818',
#     'text': '@FOREVER_SAINT I have dated women that made more. It was not an issue.',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'FOREVER_SAINT',
#        'name': 'Баба-Яга',
#        'id': 184454940,
#        'id_str': '184454940',
#        'indices': [0, 14]}],
#      'urls': []},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id': 1365448141839958017,
#     'in_reply_to_status_id_str': '1365448141839958017',
#     'in_reply_to_user_id': 184454940,
#     'in_reply_to_user_id_str': '184454940',
#     'in_reply_to_screen_name': 'FOREVER_SAINT',
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 0,
#     'favorite_count': 3,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1286571461910593536/wYHAMyUe_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1286571461910593536/wYHAMyUe_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/289814036/1410390751',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 130231048,
#    'id_str': '130231048',
#    'name': 'Vsourz',
#    'screen_name': 'vsourz_agency',
#    'location': 'London',
#    'description': 'Vsourz is a digital agency offering end to end solutions to our clients ranging from E-Commerce, Web Design, Development, Internet Marketing and beyond.',
#    'url': 'https://t.co/VWt2I4FVQt',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/VWt2I4FVQt',
#        'expanded_url': 'https://www.vsourz.com',
#        'display_url': 'vsourz.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 46,
#    'friends_count': 128,
#    'listed_count': 2,
#    'created_at': 'Tue Apr 06 18:21:40 +0000 2010',
#    'favourites_count': 3,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 5,
#    'lang': None,
#    'status': {'created_at': 'Thu Mar 04 10:32:10 +0000 2021',
#     'id': 1367422610733170689,
#     'id_str': '1367422610733170689',
#     'text': 'RT @Microsoft: Your Microsoft Teams starter pack. https://t.co/nkxttx9eGh',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'Microsoft',
#        'name': 'Microsoft',
#        'id': 74286565,
#        'id_str': '74286565',
#        'indices': [3, 13]}],
#      'urls': [],
#      'media': [{'id': 1367234077254963201,
#        'id_str': '1367234077254963201',
#        'indices': [50, 73],
#        'media_url': 'http://pbs.twimg.com/media/EvlkJjuXUAEMvM1.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/EvlkJjuXUAEMvM1.jpg',
#        'url': 'https://t.co/nkxttx9eGh',
#        'display_url': 'pic.twitter.com/nkxttx9eGh',
#        'expanded_url': 'https://twitter.com/Microsoft/status/1367234080388091909/photo/1',
#        'type': 'photo',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'large': {'w': 1920, 'h': 1080, 'resize': 'fit'},
#         'medium': {'w': 1200, 'h': 675, 'resize': 'fit'},
#         'small': {'w': 680, 'h': 383, 'resize': 'fit'}},
#        'source_status_id': 1367234080388091909,
#        'source_status_id_str': '1367234080388091909',
#        'source_user_id': 74286565,
#        'source_user_id_str': '74286565'}]},
#     'extended_entities': {'media': [{'id': 1367234077254963201,
#        'id_str': '1367234077254963201',
#        'indices': [50, 73],
#        'media_url': 'http://pbs.twimg.com/media/EvlkJjuXUAEMvM1.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/EvlkJjuXUAEMvM1.jpg',
#        'url': 'https://t.co/nkxttx9eGh',
#        'display_url': 'pic.twitter.com/nkxttx9eGh',
#        'expanded_url': 'https://twitter.com/Microsoft/status/1367234080388091909/photo/1',
#        'type': 'photo',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'large': {'w': 1920, 'h': 1080, 'resize': 'fit'},
#         'medium': {'w': 1200, 'h': 675, 'resize': 'fit'},
#         'small': {'w': 680, 'h': 383, 'resize': 'fit'}},
#        'source_status_id': 1367234080388091909,
#        'source_status_id_str': '1367234080388091909',
#        'source_user_id': 74286565,
#        'source_user_id_str': '74286565'}]},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'retweeted_status': {'created_at': 'Wed Mar 03 22:03:01 +0000 2021',
#      'id': 1367234080388091909,
#      'id_str': '1367234080388091909',
#      'text': 'Your Microsoft Teams starter pack. https://t.co/nkxttx9eGh',
#      'truncated': False,
#      'entities': {'hashtags': [],
#       'symbols': [],
#       'user_mentions': [],
#       'urls': [],
#       'media': [{'id': 1367234077254963201,
#         'id_str': '1367234077254963201',
#         'indices': [35, 58],
#         'media_url': 'http://pbs.twimg.com/media/EvlkJjuXUAEMvM1.jpg',
#         'media_url_https': 'https://pbs.twimg.com/media/EvlkJjuXUAEMvM1.jpg',
#         'url': 'https://t.co/nkxttx9eGh',
#         'display_url': 'pic.twitter.com/nkxttx9eGh',
#         'expanded_url': 'https://twitter.com/Microsoft/status/1367234080388091909/photo/1',
#         'type': 'photo',
#         'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#          'large': {'w': 1920, 'h': 1080, 'resize': 'fit'},
#          'medium': {'w': 1200, 'h': 675, 'resize': 'fit'},
#          'small': {'w': 680, 'h': 383, 'resize': 'fit'}}}]},
#      'extended_entities': {'media': [{'id': 1367234077254963201,
#         'id_str': '1367234077254963201',
#         'indices': [35, 58],
#         'media_url': 'http://pbs.twimg.com/media/EvlkJjuXUAEMvM1.jpg',
#         'media_url_https': 'https://pbs.twimg.com/media/EvlkJjuXUAEMvM1.jpg',
#         'url': 'https://t.co/nkxttx9eGh',
#         'display_url': 'pic.twitter.com/nkxttx9eGh',
#         'expanded_url': 'https://twitter.com/Microsoft/status/1367234080388091909/photo/1',
#         'type': 'photo',
#         'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#          'large': {'w': 1920, 'h': 1080, 'resize': 'fit'},
#          'medium': {'w': 1200, 'h': 675, 'resize': 'fit'},
#          'small': {'w': 680, 'h': 383, 'resize': 'fit'}}}]},
#      'source': '<a href="https://prod1.sprinklr.com" rel="nofollow">Sprinklr Publishing</a>',
#      'in_reply_to_status_id': None,
#      'in_reply_to_status_id_str': None,
#      'in_reply_to_user_id': None,
#      'in_reply_to_user_id_str': None,
#      'in_reply_to_screen_name': None,
#      'geo': None,
#      'coordinates': None,
#      'place': None,
#      'contributors': None,
#      'is_quote_status': False,
#      'retweet_count': 97,
#      'favorite_count': 974,
#      'favorited': False,
#      'retweeted': False,
#      'possibly_sensitive': False,
#      'lang': 'en'},
#     'is_quote_status': False,
#     'retweet_count': 97,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'DBE9ED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme17/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme17/bg.gif',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1362130460294447104/xkI9DJvB_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1362130460294447104/xkI9DJvB_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/130231048/1613592185',
#    'profile_link_color': 'CC3366',
#    'profile_sidebar_border_color': 'DBE9ED',
#    'profile_sidebar_fill_color': 'E6F6F9',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 1367395006684758016,
#    'id_str': '1367395006684758016',
#    'name': 'Pbekkilla',
#    'screen_name': 'pbekkilla',
#    'location': 'Richmond, VA',
#    'description': 'Independent Artist North Carolina 💪🏾💪🏾',
#    'url': 'https://t.co/ivuu7Hv0yW',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/ivuu7Hv0yW',
#        'expanded_url': 'https://unitedmasters.com/m/kkilla252',
#        'display_url': 'unitedmasters.com/m/kkilla252',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 7,
#    'friends_count': 82,
#    'listed_count': 1,
#    'created_at': 'Thu Mar 04 08:42:53 +0000 2021',
#    'favourites_count': 7,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 5,
#    'lang': None,
#    'status': {'created_at': 'Thu Mar 04 10:29:43 +0000 2021',
#     'id': 1367421994719977475,
#     'id_str': '1367421994719977475',
#     'text': '@spotifyartists \n💪🏾💪🏾 NEW Single!!! $oney Talk\nLike Share Repost stream download on spotify &amp; apple music \nClick Li… https://t.co/ay0G7i1wt3',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [{'text': 'oney', 'indices': [36, 41]}],
#      'user_mentions': [{'screen_name': 'spotifyartists',
#        'name': 'Spotify for Artists',
#        'id': 1729246746,
#        'id_str': '1729246746',
#        'indices': [0, 15]}],
#      'urls': [{'url': 'https://t.co/ay0G7i1wt3',
#        'expanded_url': 'https://twitter.com/i/web/status/1367421994719977475',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [121, 144]}]},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': 1729246746,
#     'in_reply_to_user_id_str': '1729246746',
#     'in_reply_to_screen_name': 'spotifyartists',
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 0,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1367395290425229313/pl3KcOv9_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1367395290425229313/pl3KcOv9_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1367395006684758016/1614848638',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 1009075586709577728,
#    'id_str': '1009075586709577728',
#    'name': 'The Coders Guild',
#    'screen_name': 'the_codersguild',
#    'location': 'England',
#    'description': 'Promoting inclusion, diversity and equality through expert training, coaching and CPD opportunities for software development.',
#    'url': 'https://t.co/ysIVAhqHjZ',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/ysIVAhqHjZ',
#        'expanded_url': 'https://thecodersguild.org.uk/',
#        'display_url': 'thecodersguild.org.uk',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 274,
#    'friends_count': 220,
#    'listed_count': 4,
#    'created_at': 'Tue Jun 19 14:09:02 +0000 2018',
#    'favourites_count': 472,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 823,
#    'lang': None,
#    'status': {'created_at': 'Thu Mar 04 12:05:44 +0000 2021',
#     'id': 1367446157501353990,
#     'id_str': '1367446157501353990',
#     'text': '@paultebbatt',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'paultebbatt',
#        'name': 'Paul Tebbatt',
#        'id': 46232659,
#        'id_str': '46232659',
#        'indices': [0, 12]}],
#      'urls': []},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': 1367438184171393028,
#     'in_reply_to_status_id_str': '1367438184171393028',
#     'in_reply_to_user_id': 1009075586709577728,
#     'in_reply_to_user_id_str': '1009075586709577728',
#     'in_reply_to_screen_name': 'the_codersguild',
#     'geo': None,
#     'coordinates': None,
#     'place': {'id': '6863fd050de21120',
#      'url': 'https://api.twitter.com/1.1/geo/id/6863fd050de21120.json',
#      'place_type': 'city',
#      'name': 'Leeds',
#      'full_name': 'Leeds, England',
#      'country_code': 'GB',
#      'country': 'United Kingdom',
#      'contained_within': [],
#      'bounding_box': {'type': 'Polygon',
#       'coordinates': [[[-1.706057, 53.7363694],
#         [-1.424923, 53.7363694],
#         [-1.424923, 53.867543],
#         [-1.706057, 53.867543]]]},
#      'attributes': {}},
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 0,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'und'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1161961425608302592/emST-FQ2_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1161961425608302592/emST-FQ2_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1009075586709577728/1552400628',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 1173548031758802944,
#    'id_str': '1173548031758802944',
#    'name': 'Caveat.images',
#    'screen_name': 'caveat_images',
#    'location': 'Harare',
#    'description': 'photography',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 10,
#    'friends_count': 31,
#    'listed_count': 0,
#    'created_at': 'Mon Sep 16 10:44:17 +0000 2019',
#    'favourites_count': 33,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 22,
#    'lang': None,
#    'status': {'created_at': 'Tue Mar 02 07:20:08 +0000 2021',
#     'id': 1366649509632233473,
#     'id_str': '1366649509632233473',
#     'text': 'RT @CaveatShopZW: Business is the art of extracting money from another man’s pocket without resorting to violence😎😎 https://t.co/NyAyqioT3a',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'CaveatShopZW',
#        'name': 'CaveatShopZW®',
#        'id': 132543506,
#        'id_str': '132543506',
#        'indices': [3, 16]}],
#      'urls': [],
#      'media': [{'id': 1365580215951519744,
#        'id_str': '1365580215951519744',
#        'indices': [116, 139],
#        'media_url': 'http://pbs.twimg.com/media/EvOD-KQXcAArKtj.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/EvOD-KQXcAArKtj.jpg',
#        'url': 'https://t.co/NyAyqioT3a',
#        'display_url': 'pic.twitter.com/NyAyqioT3a',
#        'expanded_url': 'https://twitter.com/CaveatShopZW/status/1365580239875809287/photo/1',
#        'type': 'photo',
#        'sizes': {'large': {'w': 800, 'h': 800, 'resize': 'fit'},
#         'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'small': {'w': 680, 'h': 680, 'resize': 'fit'},
#         'medium': {'w': 800, 'h': 800, 'resize': 'fit'}},
#        'source_status_id': 1365580239875809287,
#        'source_status_id_str': '1365580239875809287',
#        'source_user_id': 132543506,
#        'source_user_id_str': '132543506'}]},
#     'extended_entities': {'media': [{'id': 1365580215951519744,
#        'id_str': '1365580215951519744',
#        'indices': [116, 139],
#        'media_url': 'http://pbs.twimg.com/media/EvOD-KQXcAArKtj.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/EvOD-KQXcAArKtj.jpg',
#        'url': 'https://t.co/NyAyqioT3a',
#        'display_url': 'pic.twitter.com/NyAyqioT3a',
#        'expanded_url': 'https://twitter.com/CaveatShopZW/status/1365580239875809287/photo/1',
#        'type': 'photo',
#        'sizes': {'large': {'w': 800, 'h': 800, 'resize': 'fit'},
#         'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'small': {'w': 680, 'h': 680, 'resize': 'fit'},
#         'medium': {'w': 800, 'h': 800, 'resize': 'fit'}},
#        'source_status_id': 1365580239875809287,
#        'source_status_id_str': '1365580239875809287',
#        'source_user_id': 132543506,
#        'source_user_id_str': '132543506'}]},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'retweeted_status': {'created_at': 'Sat Feb 27 08:31:15 +0000 2021',
#      'id': 1365580239875809287,
#      'id_str': '1365580239875809287',
#      'text': 'Business is the art of extracting money from another man’s pocket without resorting to violence😎😎 https://t.co/NyAyqioT3a',
#      'truncated': False,
#      'entities': {'hashtags': [],
#       'symbols': [],
#       'user_mentions': [],
#       'urls': [],
#       'media': [{'id': 1365580215951519744,
#         'id_str': '1365580215951519744',
#         'indices': [98, 121],
#         'media_url': 'http://pbs.twimg.com/media/EvOD-KQXcAArKtj.jpg',
#         'media_url_https': 'https://pbs.twimg.com/media/EvOD-KQXcAArKtj.jpg',
#         'url': 'https://t.co/NyAyqioT3a',
#         'display_url': 'pic.twitter.com/NyAyqioT3a',
#         'expanded_url': 'https://twitter.com/CaveatShopZW/status/1365580239875809287/photo/1',
#         'type': 'photo',
#         'sizes': {'large': {'w': 800, 'h': 800, 'resize': 'fit'},
#          'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#          'small': {'w': 680, 'h': 680, 'resize': 'fit'},
#          'medium': {'w': 800, 'h': 800, 'resize': 'fit'}}}]},
#      'extended_entities': {'media': [{'id': 1365580215951519744,
#         'id_str': '1365580215951519744',
#         'indices': [98, 121],
#         'media_url': 'http://pbs.twimg.com/media/EvOD-KQXcAArKtj.jpg',
#         'media_url_https': 'https://pbs.twimg.com/media/EvOD-KQXcAArKtj.jpg',
#         'url': 'https://t.co/NyAyqioT3a',
#         'display_url': 'pic.twitter.com/NyAyqioT3a',
#         'expanded_url': 'https://twitter.com/CaveatShopZW/status/1365580239875809287/photo/1',
#         'type': 'photo',
#         'sizes': {'large': {'w': 800, 'h': 800, 'resize': 'fit'},
#          'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#          'small': {'w': 680, 'h': 680, 'resize': 'fit'},
#          'medium': {'w': 800, 'h': 800, 'resize': 'fit'}}}]},
#      'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#      'in_reply_to_status_id': None,
#      'in_reply_to_status_id_str': None,
#      'in_reply_to_user_id': None,
#      'in_reply_to_user_id_str': None,
#      'in_reply_to_screen_name': None,
#      'geo': None,
#      'coordinates': None,
#      'place': None,
#      'contributors': None,
#      'is_quote_status': False,
#      'retweet_count': 11,
#      'favorite_count': 24,
#      'favorited': False,
#      'retweeted': False,
#      'possibly_sensitive': False,
#      'lang': 'en'},
#     'is_quote_status': False,
#     'retweet_count': 11,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1360261968351932421/GfG4P3OG_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1360261968351932421/GfG4P3OG_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1173548031758802944/1613146703',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 979628504,
#    'id_str': '979628504',
#    'name': 'Prompt.io',
#    'screen_name': 'prompt_io',
#    'location': 'Seattle, WA',
#    'description': 'Fast, reliable, innovative text messaging, transformed into action to offer an end-to-end customer experience.',
#    'url': 'https://t.co/wz4p4rkNsc',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/wz4p4rkNsc',
#        'expanded_url': 'http://prompt.io',
#        'display_url': 'prompt.io',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 1057,
#    'friends_count': 836,
#    'listed_count': 60,
#    'created_at': 'Fri Nov 30 03:00:06 +0000 2012',
#    'favourites_count': 372,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 710,
#    'lang': None,
#    'status': {'created_at': 'Wed Mar 03 20:10:50 +0000 2021',
#     'id': 1367205850771644416,
#     'id_str': '1367205850771644416',
#     'text': 'A growing number of nonprofits are choosing https://t.co/AiJ7CqCWv2 to increase donations and boost volunteer effor… https://t.co/DfeVWa5sTM',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/AiJ7CqCWv2',
#        'expanded_url': 'http://Prompt.io',
#        'display_url': 'Prompt.io',
#        'indices': [44, 67]},
#       {'url': 'https://t.co/DfeVWa5sTM',
#        'expanded_url': 'https://twitter.com/i/web/status/1367205850771644416',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 2,
#     'favorite_count': 4,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '3B94D9',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme19/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme19/bg.gif',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1299226553314758656/LsR9xyYJ_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1299226553314758656/LsR9xyYJ_normal.png',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/979628504/1559337793',
#    'profile_link_color': '3B94D9',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 1014996589465735175,
#    'id_str': '1014996589465735175',
#    'name': "McDaniel Inks Int'l Strategic Biz Expansion Plans",
#    'screen_name': 'McDaniel_InksBz',
#    'location': 'United States',
#    'description': '@TempleUniv Global MBA writes #BusinessPlansForSBA and investors since 2001. Scribe for "The Stand" by https://t.co/WttJ1CmRj5 #BLOCKCHAIN OTT #FINTECH Int\'l Health #QOZF etc.',
#    'url': 'https://t.co/glOWBnps9M',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/glOWBnps9M',
#        'expanded_url': 'https://www.youtube.com/watch?v=rBWDg8dAL_s',
#        'display_url': 'youtube.com/watch?v=rBWDg8…',
#        'indices': [0, 23]}]},
#     'description': {'urls': [{'url': 'https://t.co/WttJ1CmRj5',
#        'expanded_url': 'http://BWBC.io',
#        'display_url': 'BWBC.io',
#        'indices': [103, 126]}]}},
#    'protected': False,
#    'followers_count': 55,
#    'friends_count': 278,
#    'listed_count': 1,
#    'created_at': 'Thu Jul 05 22:16:59 +0000 2018',
#    'favourites_count': 150,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 388,
#    'lang': None,
#    'status': {'created_at': 'Thu Feb 25 16:47:21 +0000 2021',
#     'id': 1364980313613619205,
#     'id_str': '1364980313613619205',
#     'text': 'Wonderful @skurutz  "Join Clubhouse! Umm, What Is Clubhouse?" https://t.co/BTqqdNOG3Z',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'skurutz',
#        'name': 'Steven Kurutz',
#        'id': 130826610,
#        'id_str': '130826610',
#        'indices': [10, 18]}],
#      'urls': [{'url': 'https://t.co/BTqqdNOG3Z',
#        'expanded_url': 'https://www.nytimes.com/2021/02/20/at-home/clubhouse-app-explainer.html?smid=tw-share',
#        'display_url': 'nytimes.com/2021/02/20/at-…',
#        'indices': [62, 85]}]},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 0,
#     'favorite_count': 1,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1014999706051665920/f5jgSFHi_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1014999706051665920/f5jgSFHi_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1014996589465735175/1530830490',
#    'profile_link_color': '19CF86',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 1144659283398856705,
#    'id_str': '1144659283398856705',
#    'name': 'laura',
#    'screen_name': 'Laura_Tombia',
#    'location': 'Abuja, Nigeria',
#    'description': '',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 268,
#    'friends_count': 382,
#    'listed_count': 0,
#    'created_at': 'Fri Jun 28 17:30:14 +0000 2019',
#    'favourites_count': 17593,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 3358,
#    'lang': None,
#    'status': {'created_at': 'Thu Mar 04 14:45:05 +0000 2021',
#     'id': 1367486259451604993,
#     'id_str': '1367486259451604993',
#     'text': '@Uniquenneoma @oluwakayodeA_ @TheCharlesIsidi @ugonna_t I cried too😪',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'Uniquenneoma',
#        'name': 'Vivian Amaechi',
#        'id': 1122246817536778241,
#        'id_str': '1122246817536778241',
#        'indices': [0, 13]},
#       {'screen_name': 'oluwakayodeA_',
#        'name': 'Oladipo Kayode 💙',
#        'id': 445110987,
#        'id_str': '445110987',
#        'indices': [14, 28]},
#       {'screen_name': 'TheCharlesIsidi',
#        'name': 'Mr. Charles Isidi',
#        'id': 1425363258,
#        'id_str': '1425363258',
#        'indices': [29, 45]},
#       {'screen_name': 'ugonna_t',
#        'name': 'Ugonna',
#        'id': 144624251,
#        'id_str': '144624251',
#        'indices': [46, 55]}],
#      'urls': []},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id': 1367447707359604745,
#     'in_reply_to_status_id_str': '1367447707359604745',
#     'in_reply_to_user_id': 1122246817536778241,
#     'in_reply_to_user_id_str': '1122246817536778241',
#     'in_reply_to_screen_name': 'Uniquenneoma',
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 0,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1308022921995194369/fiObyr8c_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1308022921995194369/fiObyr8c_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1144659283398856705/1600528497',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 33818375,
#    'id_str': '33818375',
#    'name': 'Britt Cambas',
#    'screen_name': 'brittcambas',
#    'location': 'Manhattan, NY',
#    'description': 'enthusiast',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': True,
#    'followers_count': 49,
#    'friends_count': 190,
#    'listed_count': 2,
#    'created_at': 'Tue Apr 21 04:59:47 +0000 2009',
#    'favourites_count': 86,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 90,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme10/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme10/bg.gif',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1366097874770157573/hKMMvhFy_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1366097874770157573/hKMMvhFy_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/33818375/1491076429',
#    'profile_link_color': '7FDBB6',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 1307039155763974145,
#    'id_str': '1307039155763974145',
#    'name': 'Rekt Ralph',
#    'screen_name': 'RektRalph4',
#    'location': '',
#    'description': 'I like turtles.',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 40,
#    'friends_count': 1245,
#    'listed_count': 0,
#    'created_at': 'Fri Sep 18 19:30:09 +0000 2020',
#    'favourites_count': 10800,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 328,
#    'lang': None,
#    'status': {'created_at': 'Thu Mar 04 01:34:59 +0000 2021',
#     'id': 1367287422694883328,
#     'id_str': '1367287422694883328',
#     'text': 'RT @CalebJHull: The White House was not happy that Biden tried to take questions....  https://t.co/RU33w6SvE0',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'CalebJHull',
#        'name': "Caleb Hull (I'm With the CCP Don't Ban Me)",
#        'id': 239005322,
#        'id_str': '239005322',
#        'indices': [3, 14]}],
#      'urls': [],
#      'media': [{'id': 1367259099554074625,
#        'id_str': '1367259099554074625',
#        'indices': [86, 109],
#        'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1367259099554074625/pu/img/eoc07Z-OL5RaTrwX.jpg',
#        'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1367259099554074625/pu/img/eoc07Z-OL5RaTrwX.jpg',
#        'url': 'https://t.co/RU33w6SvE0',
#        'display_url': 'pic.twitter.com/RU33w6SvE0',
#        'expanded_url': 'https://twitter.com/TheFirstonTV/status/1367259255699562504/video/1',
#        'type': 'photo',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'large': {'w': 640, 'h': 360, 'resize': 'fit'},
#         'medium': {'w': 640, 'h': 360, 'resize': 'fit'},
#         'small': {'w': 640, 'h': 360, 'resize': 'fit'}},
#        'source_status_id': 1367259255699562504,
#        'source_status_id_str': '1367259255699562504',
#        'source_user_id': 1182332284403376128,
#        'source_user_id_str': '1182332284403376128'}]},
#     'extended_entities': {'media': [{'id': 1367259099554074625,
#        'id_str': '1367259099554074625',
#        'indices': [86, 109],
#        'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1367259099554074625/pu/img/eoc07Z-OL5RaTrwX.jpg',
#        'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1367259099554074625/pu/img/eoc07Z-OL5RaTrwX.jpg',
#        'url': 'https://t.co/RU33w6SvE0',
#        'display_url': 'pic.twitter.com/RU33w6SvE0',
#        'expanded_url': 'https://twitter.com/TheFirstonTV/status/1367259255699562504/video/1',
#        'type': 'video',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'large': {'w': 640, 'h': 360, 'resize': 'fit'},
#         'medium': {'w': 640, 'h': 360, 'resize': 'fit'},
#         'small': {'w': 640, 'h': 360, 'resize': 'fit'}},
# ...
#    'url': 'http://t.co/BULW5M9pp9',
#    'entities': {'url': {'urls': [{'url': 'http://t.co/BULW5M9pp9',
#        'expanded_url': 'http://www.linkedin.com/in/freddieblicher',
#        'display_url': 'linkedin.com/in/freddieblic…',
#        'indices': [0, 22]}]},
#     'description': {'urls': []}},
#    'protected': True,
#    'followers_count': 296,
#    'friends_count': 328,
#    'listed_count': 36,
#    'created_at': 'Sun Jun 08 17:18:35 +0000 2008',
#    'favourites_count': 333,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 315,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1291746106267893760/RgVdgPwy_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1291746106267893760/RgVdgPwy_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 3384567429,
#    'id_str': '3384567429',
#    'name': 'Brydg',
#    'screen_name': 'Brydgcom',
#    'location': 'United Kingdom',
#    'description': 'Technology enabled real estate lending for the most sophisticated loan originators. FCA regulated and CBILS accredited.\xa0',
#    'url': 'https://t.co/FG6sIDKmHM',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/FG6sIDKmHM',
#        'expanded_url': 'http://brydg.com',
#        'display_url': 'brydg.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 81,
#    'friends_count': 649,
#    'listed_count': 1,
#    'created_at': 'Mon Jul 20 15:19:32 +0000 2015',
#    'favourites_count': 7,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 32,
#    'lang': None,
#    'status': {'created_at': 'Thu Mar 04 17:03:37 +0000 2021',
#     'id': 1367521124121251843,
#     'id_str': '1367521124121251843',
#     'text': 'Brydg is pleased to announce the completion of a loan of more than £2M for a property in Alresford – facilitated by… https://t.co/qYWqxZTe77',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/qYWqxZTe77',
#        'expanded_url': 'https://twitter.com/i/web/status/1367521124121251843',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 0,
#     'favorite_count': 1,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1328738807395577856/SWX4ZsPL_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1328738807395577856/SWX4ZsPL_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3384567429/1551971577',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 989195135291461633,
#    'id_str': '989195135291461633',
#    'name': 'Mynameisflo☮️',
#    'screen_name': 'Mynameisflo1',
#    'location': 'Toronto ',
#    'description': 'Supermom💕, MLT🔬',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 34,
#    'friends_count': 846,
#    'listed_count': 0,
#    'created_at': 'Wed Apr 25 17:31:13 +0000 2018',
#    'favourites_count': 20,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 28,
#    'lang': None,
#    'status': {'created_at': 'Tue Jan 19 21:21:00 +0000 2021',
#     'id': 1351640826716282881,
#     'id_str': '1351640826716282881',
#     'text': "RT @OnTheHub: It's the 2nd week of our annual #DropTheDebt Giveaway, brought to you by Microsoft and @OnTheHub. Enter now and refer your fr…",
#     'truncated': False,
#     'entities': {'hashtags': [{'text': 'DropTheDebt', 'indices': [46, 58]}],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'OnTheHub',
#        'name': 'OnTheHub',
#        'id': 22485144,
#        'id_str': '22485144',
#        'indices': [3, 12]},
#       {'screen_name': 'OnTheHub',
#        'name': 'OnTheHub',
#        'id': 22485144,
#        'id_str': '22485144',
#        'indices': [101, 110]}],
#      'urls': []},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'retweeted_status': {'created_at': 'Mon Jan 18 14:53:16 +0000 2021',
#      'id': 1351180864856731653,
#      'id_str': '1351180864856731653',
#      'text': "It's the 2nd week of our annual #DropTheDebt Giveaway, brought to you by Microsoft and @OnTheHub. Enter now and ref… https://t.co/e5AiqK1dib",
#      'truncated': True,
#      'entities': {'hashtags': [{'text': 'DropTheDebt', 'indices': [32, 44]}],
#       'symbols': [],
#       'user_mentions': [{'screen_name': 'OnTheHub',
#         'name': 'OnTheHub',
#         'id': 22485144,
#         'id_str': '22485144',
#         'indices': [87, 96]}],
#       'urls': [{'url': 'https://t.co/e5AiqK1dib',
#         'expanded_url': 'https://twitter.com/i/web/status/1351180864856731653',
#         'display_url': 'twitter.com/i/web/status/1…',
#         'indices': [117, 140]}]},
#      'source': '<a href="http://www.hubspot.com/" rel="nofollow">HubSpot</a>',
#      'in_reply_to_status_id': None,
#      'in_reply_to_status_id_str': None,
#      'in_reply_to_user_id': None,
#      'in_reply_to_user_id_str': None,
#      'in_reply_to_screen_name': None,
#      'geo': None,
#      'coordinates': None,
#      'place': None,
#      'contributors': None,
#      'is_quote_status': False,
#      'retweet_count': 619,
#      'favorite_count': 108,
#      'favorited': False,
#      'retweeted': False,
#      'possibly_sensitive': False,
#      'lang': 'en'},
#     'is_quote_status': False,
#     'retweet_count': 619,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/990286635853144066/kY8saUBH_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/990286635853144066/kY8saUBH_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 1366782366266626053,
#    'id_str': '1366782366266626053',
#    'name': 'Florence',
#    'screen_name': 'flossybops',
#    'location': 'United Kingdom',
#    'description': '#onlyfans ➕size/curvaceous, daily messages, conversations, pictures and more',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 66,
#    'friends_count': 387,
#    'listed_count': 0,
#    'created_at': 'Tue Mar 02 16:08:15 +0000 2021',
#    'favourites_count': 13,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 15,
#    'lang': None,
#    'status': {'created_at': 'Wed Mar 03 18:57:05 +0000 2021',
#     'id': 1367187287872831498,
#     'id_str': '1367187287872831498',
#     'text': 'RT @AbiRatchford: Yay or nay? https://t.co/aajFmoIZws',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'AbiRatchford',
#        'name': 'Abigail Ratchford',
#        'id': 772601706,
#        'id_str': '772601706',
#        'indices': [3, 16]}],
#      'urls': [],
#      'media': [{'id': 1367187017952497664,
#        'id_str': '1367187017952497664',
#        'indices': [30, 53],
#        'media_url': 'http://pbs.twimg.com/media/Evk5WWKVkAA9Fnw.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/Evk5WWKVkAA9Fnw.jpg',
#        'url': 'https://t.co/aajFmoIZws',
#        'display_url': 'pic.twitter.com/aajFmoIZws',
#        'expanded_url': 'https://twitter.com/AbiRatchford/status/1367187021869895682/photo/1',
#        'type': 'photo',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'small': {'w': 432, 'h': 680, 'resize': 'fit'},
#         'large': {'w': 988, 'h': 1555, 'resize': 'fit'},
#         'medium': {'w': 762, 'h': 1200, 'resize': 'fit'}},
#        'source_status_id': 1367187021869895682,
#        'source_status_id_str': '1367187021869895682',
#        'source_user_id': 772601706,
#        'source_user_id_str': '772601706'}]},
#     'extended_entities': {'media': [{'id': 1367187017952497664,
#        'id_str': '1367187017952497664',
#        'indices': [30, 53],
#        'media_url': 'http://pbs.twimg.com/media/Evk5WWKVkAA9Fnw.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/Evk5WWKVkAA9Fnw.jpg',
#        'url': 'https://t.co/aajFmoIZws',
#        'display_url': 'pic.twitter.com/aajFmoIZws',
#        'expanded_url': 'https://twitter.com/AbiRatchford/status/1367187021869895682/photo/1',
#        'type': 'photo',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'small': {'w': 432, 'h': 680, 'resize': 'fit'},
#         'large': {'w': 988, 'h': 1555, 'resize': 'fit'},
#         'medium': {'w': 762, 'h': 1200, 'resize': 'fit'}},
#        'source_status_id': 1367187021869895682,
#        'source_status_id_str': '1367187021869895682',
#        'source_user_id': 772601706,
#        'source_user_id_str': '772601706'}]},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'retweeted_status': {'created_at': 'Wed Mar 03 18:56:01 +0000 2021',
#      'id': 1367187021869895682,
#      'id_str': '1367187021869895682',
#      'text': 'Yay or nay? https://t.co/aajFmoIZws',
#      'truncated': False,
#      'entities': {'hashtags': [],
#       'symbols': [],
#       'user_mentions': [],
#       'urls': [],
#       'media': [{'id': 1367187017952497664,
#         'id_str': '1367187017952497664',
#         'indices': [12, 35],
#         'media_url': 'http://pbs.twimg.com/media/Evk5WWKVkAA9Fnw.jpg',
#         'media_url_https': 'https://pbs.twimg.com/media/Evk5WWKVkAA9Fnw.jpg',
#         'url': 'https://t.co/aajFmoIZws',
#         'display_url': 'pic.twitter.com/aajFmoIZws',
#         'expanded_url': 'https://twitter.com/AbiRatchford/status/1367187021869895682/photo/1',
#         'type': 'photo',
#         'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#          'small': {'w': 432, 'h': 680, 'resize': 'fit'},
#          'large': {'w': 988, 'h': 1555, 'resize': 'fit'},
#          'medium': {'w': 762, 'h': 1200, 'resize': 'fit'}}}]},
#      'extended_entities': {'media': [{'id': 1367187017952497664,
#         'id_str': '1367187017952497664',
#         'indices': [12, 35],
#         'media_url': 'http://pbs.twimg.com/media/Evk5WWKVkAA9Fnw.jpg',
#         'media_url_https': 'https://pbs.twimg.com/media/Evk5WWKVkAA9Fnw.jpg',
#         'url': 'https://t.co/aajFmoIZws',
#         'display_url': 'pic.twitter.com/aajFmoIZws',
#         'expanded_url': 'https://twitter.com/AbiRatchford/status/1367187021869895682/photo/1',
#         'type': 'photo',
#         'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#          'small': {'w': 432, 'h': 680, 'resize': 'fit'},
#          'large': {'w': 988, 'h': 1555, 'resize': 'fit'},
#          'medium': {'w': 762, 'h': 1200, 'resize': 'fit'}}}]},
#      'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#      'in_reply_to_status_id': None,
#      'in_reply_to_status_id_str': None,
#      'in_reply_to_user_id': None,
#      'in_reply_to_user_id_str': None,
#      'in_reply_to_screen_name': None,
#      'geo': None,
#      'coordinates': None,
#      'place': None,
#      'contributors': None,
#      'is_quote_status': False,
#      'retweet_count': 377,
#      'favorite_count': 9052,
#      'favorited': False,
#      'retweeted': False,
#      'possibly_sensitive': False,
#      'lang': 'en'},
#     'is_quote_status': False,
#     'retweet_count': 377,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1366834569102688258/KLCbLkcc_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1366834569102688258/KLCbLkcc_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1366782366266626053/1614713751',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'}],
#  'next_cursor': 1693150371228573149,
#  'next_cursor_str': '1693150371228573149',
#  'previous_cursor': 0,
#  'previous_cursor_str': '0',
#  'total_count': None}
